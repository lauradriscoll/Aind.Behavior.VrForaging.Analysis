# %% [markdown]
# # Enhanced Feature Visualizations (31 Features)
#
# This notebook visualizes how all 31 summary statistics respond to changes in DDM parameters.

# %%
import os
# Force CPU backend on Apple Silicon to avoid Metal issues
os.environ['JAX_PLATFORMS'] = 'cpu'

# === Setup ===
import numpy as np
import matplotlib.pyplot as plt
import jax.numpy as jnp
from jax import random
import seaborn as sns
from scipy.stats import spearmanr, pearsonr
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance

from aind_behavior_vrforaging_analysis.sbi_ddm_analysis.simulator import PatchForagingDDM_JAX, create_prior

# Reproducibility
np.random.seed(1)
rng_key = random.PRNGKey(42)

# %%
def comprehensive_feature_importance_analysis(simulator, prior_fn, feature_names, n_samples=2000):
    """
    Comprehensive analysis to identify most informative features for each parameter
    
    Returns rankings, plots, and recommendations
    """
    
    print("="*70)
    print("COMPREHENSIVE FEATURE IMPORTANCE ANALYSIS")
    print("="*70)
    
    # =========================================================================
    # 1. GENERATE DATA
    # =========================================================================
    print(f"\nGenerating {n_samples} samples from prior...")
    
    rng_key = random.PRNGKey(42)
    thetas = []
    stats = []
    
    for i in range(n_samples):
        if i % 200 == 0:
            print(f"  {i}/{n_samples}...")
        
        rng_key, subkey1, subkey2 = random.split(rng_key, 3)
        theta = prior_fn().sample(seed=subkey1)['theta']
        _, summary_stats = simulator.simulate_one_window(theta, subkey2)
        
        thetas.append(theta)
        stats.append(summary_stats)
    
    thetas = jnp.array(thetas)
    stats = jnp.array(stats)
    
    param_names = ['drift_rate', 'reward_bump', 'failure_bump', 'noise_std']
    n_features = len(feature_names)
    n_params = len(param_names)
    
    print(f"\n✓ Generated data shape: thetas={thetas.shape}, stats={stats.shape}")
    
    # =========================================================================
    # 2. CORRELATION ANALYSIS (LINEAR RELATIONSHIPS)
    # =========================================================================
    print("\n" + "="*70)
    print("METHOD 1: CORRELATION ANALYSIS")
    print("="*70)
    
    correlation_results = {}
    
    for i, param in enumerate(param_names):
        correlations = []
        for j in range(n_features):
            # Pearson correlation (linear)
            r_pearson, _ = pearsonr(np.array(thetas[:, i]), np.array(stats[:, j]))
            # Spearman correlation (monotonic)
            r_spearman, _ = spearmanr(np.array(thetas[:, i]), np.array(stats[:, j]))
            
            correlations.append({
                'feature': feature_names[j],
                'feature_idx': j,
                'pearson': r_pearson,
                'spearman': r_spearman,
                'abs_pearson': abs(r_pearson),
                'abs_spearman': abs(r_spearman),
            })
        
        # Sort by absolute correlation
        correlations.sort(key=lambda x: x['abs_spearman'], reverse=True)
        correlation_results[param] = correlations
        
        print(f"\n{param} - Top 10 correlated features:")
        print(f"  {'Rank':<6} {'Feature':<30} {'Pearson':>10} {'Spearman':>10}")
        print("  " + "-"*60)
        for rank, c in enumerate(correlations[:10], 1):
            print(f"  {rank:<6} {c['feature']:<30} {c['pearson']:>10.3f} {c['spearman']:>10.3f}")
    
    # =========================================================================
    # 3. MUTUAL INFORMATION (NONLINEAR RELATIONSHIPS)
    # =========================================================================
    print("\n" + "="*70)
    print("METHOD 2: MUTUAL INFORMATION")
    print("="*70)
    
    from sklearn.feature_selection import mutual_info_regression
    
    mi_results = {}
    
    for i, param in enumerate(param_names):
        # Compute MI for all features
        mi_scores = mutual_info_regression(
            np.array(stats), 
            np.array(thetas[:, i]),
            random_state=42
        )
        
        mi_list = [
            {'feature': feature_names[j], 'feature_idx': j, 'mi': mi_scores[j]}
            for j in range(n_features)
        ]
        mi_list.sort(key=lambda x: x['mi'], reverse=True)
        mi_results[param] = mi_list
        
        print(f"\n{param} - Top 10 by Mutual Information:")
        print(f"  {'Rank':<6} {'Feature':<30} {'MI Score':>12}")
        print("  " + "-"*50)
        for rank, m in enumerate(mi_list[:10], 1):
            print(f"  {rank:<6} {m['feature']:<30} {m['mi']:>12.4f}")
    
    # =========================================================================
    # 4. RANDOM FOREST FEATURE IMPORTANCE
    # =========================================================================
    print("\n" + "="*70)
    print("METHOD 3: RANDOM FOREST IMPORTANCE")
    print("="*70)
    
    rf_results = {}
    
    for i, param in enumerate(param_names):
        print(f"\nTraining Random Forest for {param}...")
        
        # Train Random Forest
        rf = RandomForestRegressor(
            n_estimators=100,
            max_depth=10,
            random_state=42,
            n_jobs=-1
        )
        rf.fit(np.array(stats), np.array(thetas[:, i]))
        
        # Get feature importances
        importances = rf.feature_importances_
        
        # Permutation importance (more robust)
        perm_importance = permutation_importance(
            rf, np.array(stats), np.array(thetas[:, i]),
            n_repeats=10, random_state=42, n_jobs=-1
        )
        
        rf_list = [
            {
                'feature': feature_names[j],
                'feature_idx': j,
                'importance': importances[j],
                'perm_importance': perm_importance.importances_mean[j],
                'perm_std': perm_importance.importances_std[j],
            }
            for j in range(n_features)
        ]
        rf_list.sort(key=lambda x: x['perm_importance'], reverse=True)
        rf_results[param] = rf_list
        
        print(f"\n{param} - Top 10 by Random Forest:")
        print(f"  {'Rank':<6} {'Feature':<30} {'Importance':>12} {'Perm.Imp':>12}")
        print("  " + "-"*62)
        for rank, r in enumerate(rf_list[:10], 1):
            print(f"  {rank:<6} {r['feature']:<30} {r['importance']:>12.4f} "
                  f"{r['perm_importance']:>12.4f}")
    
    # =========================================================================
    # 5. LASSO REGRESSION (SPARSE FEATURE SELECTION)
    # =========================================================================
    print("\n" + "="*70)
    print("METHOD 4: LASSO SPARSE SELECTION")
    print("="*70)
    
    from sklearn.linear_model import LassoCV
    from sklearn.preprocessing import StandardScaler
    
    # Standardize features
    scaler = StandardScaler()
    stats_scaled = scaler.fit_transform(np.array(stats))
    
    lasso_results = {}
    
    for i, param in enumerate(param_names):
        print(f"\nRunning LASSO for {param}...")
        
        # LASSO with cross-validation
        lasso = LassoCV(cv=5, random_state=42, max_iter=5000)
        lasso.fit(stats_scaled, np.array(thetas[:, i]))
        
        # Get non-zero coefficients
        lasso_list = [
            {
                'feature': feature_names[j],
                'feature_idx': j,
                'coefficient': lasso.coef_[j],
                'abs_coefficient': abs(lasso.coef_[j]),
            }
            for j in range(n_features)
        ]
        lasso_list.sort(key=lambda x: x['abs_coefficient'], reverse=True)
        lasso_results[param] = lasso_list
        
        # Count selected features
        n_selected = sum(1 for l in lasso_list if abs(l['coefficient']) > 0.001)
        
        print(f"\n{param} - LASSO selected {n_selected}/{n_features} features")
        print(f"  Alpha: {lasso.alpha_:.6f}, R²: {lasso.score(stats_scaled, np.array(thetas[:, i])):.3f}")
        print(f"\n  {'Rank':<6} {'Feature':<30} {'Coefficient':>15}")
        print("  " + "-"*53)
        for rank, l in enumerate([x for x in lasso_list if abs(x['coefficient']) > 0.001][:10], 1):
            print(f"  {rank:<6} {l['feature']:<30} {l['coefficient']:>15.6f}")
    
    # =========================================================================
    # 6. ENSEMBLE RANKING (COMBINE ALL METHODS)
    # =========================================================================
    print("\n" + "="*70)
    print("METHOD 5: ENSEMBLE RANKING")
    print("="*70)
    
    ensemble_results = {}
    
    for param in param_names:
        # Collect rankings from each method
        feature_scores = {fname: {'ranks': [], 'scores': []} for fname in feature_names}
        
        # Add correlation ranks
        for rank, item in enumerate(correlation_results[param], 1):
            feature_scores[item['feature']]['ranks'].append(rank)
            feature_scores[item['feature']]['scores'].append(item['abs_spearman'])
        
        # Add MI ranks
        for rank, item in enumerate(mi_results[param], 1):
            feature_scores[item['feature']]['ranks'].append(rank)
            feature_scores[item['feature']]['scores'].append(item['mi'])
        
        # Add RF ranks
        for rank, item in enumerate(rf_results[param], 1):
            feature_scores[item['feature']]['ranks'].append(rank)
            feature_scores[item['feature']]['scores'].append(item['perm_importance'])
        
        # Add LASSO ranks
        for rank, item in enumerate(lasso_results[param], 1):
            feature_scores[item['feature']]['ranks'].append(rank)
            feature_scores[item['feature']]['scores'].append(item['abs_coefficient'])
        
        # Compute ensemble score (average rank, lower is better)
        ensemble_list = []
        for fname, data in feature_scores.items():
            avg_rank = np.mean(data['ranks'])
            min_rank = min(data['ranks'])
            max_rank = max(data['ranks'])
            
            ensemble_list.append({
                'feature': fname,
                'avg_rank': avg_rank,
                'min_rank': min_rank,
                'max_rank': max_rank,
                'rank_std': np.std(data['ranks']),
            })
        
        ensemble_list.sort(key=lambda x: x['avg_rank'])
        ensemble_results[param] = ensemble_list
        
        print(f"\n{param} - ENSEMBLE RANKING (lower rank = more important):")
        print(f"  {'Rank':<6} {'Feature':<30} {'Avg Rank':>10} {'Best':>6} {'Worst':>6} {'Std':>6}")
        print("  " + "-"*70)
        for rank, e in enumerate(ensemble_list[:15], 1):
            print(f"  {rank:<6} {e['feature']:<30} {e['avg_rank']:>10.1f} "
                  f"{e['min_rank']:>6.0f} {e['max_rank']:>6.0f} {e['rank_std']:>6.1f}")
    
    # =========================================================================
    # 7. VISUALIZATIONS
    # =========================================================================
    print("\n" + "="*70)
    print("GENERATING VISUALIZATIONS")
    print("="*70)
    
    # Plot 1: Heatmap of feature importance across methods
    fig, axes = plt.subplots(2, 2, figsize=(20, 16))
    
    for idx, (ax, param) in enumerate(zip(axes.flat, param_names)):
        # Get top 15 features from ensemble
        top_features = [e['feature'] for e in ensemble_results[param][:15]]
        
        # Create importance matrix
        methods = ['Correlation', 'Mutual Info', 'Random Forest', 'LASSO']
        importance_matrix = np.zeros((len(top_features), len(methods)))
        
        for i, fname in enumerate(top_features):
            # Correlation (normalized)
            corr_item = next(c for c in correlation_results[param] if c['feature'] == fname)
            importance_matrix[i, 0] = corr_item['abs_spearman']
            
            # MI (normalized)
            mi_item = next(m for m in mi_results[param] if m['feature'] == fname)
            importance_matrix[i, 1] = mi_item['mi'] / max(m['mi'] for m in mi_results[param])
            
            # RF (normalized)
            rf_item = next(r for r in rf_results[param] if r['feature'] == fname)
            importance_matrix[i, 2] = rf_item['perm_importance'] / max(r['perm_importance'] for r in rf_results[param])
            
            # LASSO (normalized)
            lasso_item = next(l for l in lasso_results[param] if l['feature'] == fname)
            importance_matrix[i, 3] = lasso_item['abs_coefficient'] / max(l['abs_coefficient'] for l in lasso_results[param])
        
        sns.heatmap(importance_matrix, ax=ax, cmap='YlOrRd', 
                   xticklabels=methods, yticklabels=top_features,
                   cbar_kws={'label': 'Normalized Importance'},
                   vmin=0, vmax=1, annot=True, fmt='.2f')
        ax.set_title(f'{param} - Top 15 Features', fontsize=14, fontweight='bold')
        ax.set_xlabel('Method', fontsize=12)
        ax.set_ylabel('Feature', fontsize=12)
    
    plt.tight_layout()
    plt.savefig('feature_importance_heatmap.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("✓ Saved: feature_importance_heatmap.png")
    
    # Plot 2: Scatter plots of top features vs parameters
    fig, axes = plt.subplots(4, 4, figsize=(20, 16))
    
    for i, param in enumerate(param_names):
        top_4_features = [e['feature'] for e in ensemble_results[param][:4]]
        
        for j, fname in enumerate(top_4_features):
            ax = axes[i, j]
            feat_idx = feature_names.index(fname)
            
            ax.scatter(stats[:, feat_idx], thetas[:, i], alpha=0.3, s=1)
            ax.set_xlabel(fname, fontsize=10)
            ax.set_ylabel(param if j == 0 else '', fontsize=10)
            
            # Add correlation
            r = correlation_results[param][next(k for k, c in enumerate(correlation_results[param]) if c['feature'] == fname)]['spearman']
            ax.set_title(f'ρ={r:.3f}', fontsize=9)
            ax.grid(True, alpha=0.3)
    
    plt.suptitle('Top 4 Features for Each Parameter', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig('top_features_scatter.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("✓ Saved: top_features_scatter.png")
    
    # =========================================================================
    # 8. RECOMMENDATIONS
    # =========================================================================
    print("\n" + "="*70)
    print("FEATURE SELECTION RECOMMENDATIONS")
    print("="*70)
    
    # Find features that appear in top 10 for multiple parameters
    feature_frequency = {}
    for fname in feature_names:
        count = sum(
            1 for param in param_names 
            if fname in [e['feature'] for e in ensemble_results[param][:10]]
        )
        if count > 0:
            feature_frequency[fname] = count
    
    print("\nFeatures appearing in top 10 for multiple parameters:")
    for fname, count in sorted(feature_frequency.items(), key=lambda x: x[1], reverse=True):
        params = [p for p in param_names if fname in [e['feature'] for e in ensemble_results[p][:10]]]
        print(f"  {fname:<30} → {count} parameters: {', '.join(params)}")
    
    # Recommend minimal feature set
    print("\n" + "="*70)
    print("RECOMMENDED MINIMAL FEATURE SETS")
    print("="*70)
    
    for n_features_target in [10, 15, 20]:
        print(f"\nTop {n_features_target} features (union across all parameters):")
        
        # Collect top N from each parameter
        selected = set()
        for param in param_names:
            selected.update([e['feature'] for e in ensemble_results[param][:n_features_target//2]])
        
        # Sort by frequency
        selected_list = sorted(
            selected,
            key=lambda x: sum(1 for p in param_names if x in [e['feature'] for e in ensemble_results[p][:10]]),
            reverse=True
        )[:n_features_target]
        
        print(f"  Total: {len(selected_list)} features")
        for fname in selected_list:
            # Find which parameters this feature is top-10 for
            good_for = [p for p in param_names if fname in [e['feature'] for e in ensemble_results[p][:10]]]
            print(f"    {fname:<30} → {', '.join(good_for) if good_for else 'general'}")
    
    return {
        'correlation': correlation_results,
        'mutual_info': mi_results,
        'random_forest': rf_results,
        'lasso': lasso_results,
        'ensemble': ensemble_results,
        'data': (thetas, stats)
    }

# %%
# For 35-feature model
from aind_behavior_vrforaging_analysis.sbi_ddm_analysis.enhanced_stats_35 import FEATURE_NAMES  # 35 features


# Initialize simulator
simulator_35 = PatchForagingDDM_JAX(max_sites_per_window=100)
prior_fn = create_prior()

results_35 = comprehensive_feature_importance_analysis(
    simulator_35,  # Your 35-feature simulator
    prior_fn,
    FEATURE_NAMES,
    n_samples=2000
)
# Out:
# ======================================================================
# COMPREHENSIVE FEATURE IMPORTANCE ANALYSIS
# ======================================================================
#
# Generating 2000 samples from prior...
#   0/2000...
#   200/2000...
#   400/2000...
#   600/2000...
#   800/2000...
#   1000/2000...
#   1200/2000...
#   1400/2000...
#   1600/2000...
#   1800/2000...
#
# ✓ Generated data shape: thetas=(2000, 4), stats=(2000, 35)
#
# ======================================================================
# METHOD 1: CORRELATION ANALYSIS
# ======================================================================
#
# drift_rate - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      stop_rate                          -0.935     -0.929
#   2      mean_sites_per_patch               -0.462     -0.929
#   3      median                             -0.494     -0.833
#   4      max_time                              nan     -0.828
#   5      early_mean                         -0.646     -0.824
#   6      mean_time_after_reward             -0.616     -0.813
#   7      iqr                                -0.539     -0.806
#   8      std_time                           -0.569     -0.796
#   9      detrended_variance                 -0.395     -0.791
#   10     after_reward_cv                    -0.780     -0.783
#
# reward_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      local_deviation                    -0.494     -0.552
#   2      autocorr_lag2                       0.538      0.530
#   3      std_time                            0.363      0.474
#   4      autocorr_lag1                       0.302      0.472
#   5      after_reward_cv                     0.463      0.462
#   6      mean_time_after_reward              0.366      0.454
#   7      reward_effect_predictability       -0.453     -0.445
#   8      iqr                                 0.344      0.444
#   9      cv_overall                          0.417      0.435
#   10     max_time                              nan      0.427
#
# failure_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      failure_bump_magnitude              0.266      0.201
#   2      immediate_failure_effect            0.266      0.201
#   3      failure_streak_effect               0.247      0.151
#   4      autocorr_lag2                      -0.126     -0.125
#   5      local_deviation                     0.106      0.119
#   6      failure_sensitivity                 0.050      0.117
#   7      autocorr_lag1                      -0.006     -0.104
#   8      early_mean                         -0.216     -0.091
#   9      median                             -0.243     -0.090
#   10     iqr                                -0.237     -0.090
#
# noise_std - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      outlier_rate                        0.236      0.233
#   2      after_failure_cv                    0.147      0.224
#   3      range_iqr_ratio                       nan      0.205
#   4      mean_reward_trial                   0.315      0.199
#   5      cv_overall                          0.198      0.165
#   6      detrended_variance                  0.024      0.164
#   7      max_time                              nan      0.152
#   8      reward_variability_ratio            0.169      0.145
#   9      diff_std                            0.151      0.142
#   10     transition_reliability             -0.180     -0.142
#
# ======================================================================
# METHOD 2: MUTUAL INFORMATION
# ======================================================================
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4751: RuntimeWarning: invalid value encountered in subtract
#   ym = y - ymean
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 9
#       6 simulator_35 = PatchForagingDDM_JAX(max_sites_per_window=100)
#       7 prior_fn = create_prior()
# ----> 9 results_35 = comprehensive_feature_importance_analysis(
#      10     simulator_35,  # Your 35-feature simulator
#      11     prior_fn,
#      12     FEATURE_NAMES,
#      13     n_samples=2000
#      14 )
#
# Cell In[2], line 90, in comprehensive_feature_importance_analysis(simulator, prior_fn, feature_names, n_samples)
#      86 mi_results = {}
#      88 for i, param in enumerate(param_names):
#      89     # Compute MI for all features
# ---> 90     mi_scores = mutual_info_regression(
#      91         np.array(stats),
#      92         np.array(thetas[:, i]),
#      93         random_state=42
#      94     )
#      96     mi_list = [
#      97         {'feature': feature_names[j], 'feature_idx': j, 'mi': mi_scores[j]}
#      98         for j in range(n_features)
#      99     ]
#     100     mi_list.sort(key=lambda x: x['mi'], reverse=True)
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/feature_selection/_mutual_info.py:441, in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     325 @validate_params(
#     326     {
#     327         "X": ["array-like", "sparse matrix"],
#    (...)    345     n_jobs=None,
#     346 ):
#     347     """Estimate mutual information for a continuous target variable.
#     348
#     349     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)    439     array([0.117, 2.645, 0.0287])
#     440     """
# --> 441     return _estimate_mi(
#     442         X,
#     443         y,
#     444         discrete_features=discrete_features,
#     445         discrete_target=False,
#     446         n_neighbors=n_neighbors,
#     447         copy=copy,
#     448         random_state=random_state,
#     449         n_jobs=n_jobs,
#     450     )
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/feature_selection/_mutual_info.py:271, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state, n_jobs)
#     202 def _estimate_mi(
#     203     X,
#     204     y,
#    (...)    211     n_jobs=None,
#     212 ):
#     213     """Estimate mutual information between the features and the target.
#     214
#     215     Parameters
#    (...)    269            Data Sets". PLoS ONE 9(2), 2014.
#     270     """
# --> 271     X, y = check_X_y(X, y, accept_sparse="csc", y_numeric=not discrete_target)
#     272     n_samples, n_features = X.shape
#     274     if isinstance(discrete_features, (str, bool)):
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/utils/validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/utils/validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float32').

# %%
# For 37-feature model
from aind_behavior_vrforaging_analysis.sbi_ddm_analysis.enhanced_stats_37 import FEATURE_NAMES  # 37 features


# Initialize simulator
simulator_37 = PatchForagingDDM_JAX(max_sites_per_window=100)
prior_fn = create_prior()

results_37 = comprehensive_feature_importance_analysis(
    simulator_37,  # Your 37-feature simulator
    prior_fn,
    FEATURE_NAMES,
    n_samples=2000
)
# Out:
# ======================================================================
# COMPREHENSIVE FEATURE IMPORTANCE ANALYSIS
# ======================================================================
#
# Generating 2000 samples from prior...
#   0/2000...
#   200/2000...
#   400/2000...
#   600/2000...
#   800/2000...
#   1000/2000...
#   1200/2000...
#   1400/2000...
#   1600/2000...
#   1800/2000...
#
# ✓ Generated data shape: thetas=(2000, 4), stats=(2000, 37)
#
# ======================================================================
# METHOD 1: CORRELATION ANALYSIS
# ======================================================================
#
# drift_rate - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      mean_sites_per_patch                0.613      0.929
#   2      mean_stops                         -0.935     -0.929
#   3      n_patches                          -0.935     -0.929
#   4      stop_rate                          -0.935     -0.929
#   5      mean_time_after_failure            -0.510     -0.850
#   6      p25                                -0.468     -0.850
#   7      std_time_after_failure             -0.596     -0.848
#   8      mean_rewards                       -0.867     -0.836
#   9      late_mean                          -0.444     -0.834
#   10     middle_mean                        -0.521     -0.834
#
# reward_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      iqr                                 0.352      0.482
#   2      std_time                            0.363      0.474
#   3      autocorr_lag1                       0.302      0.472
#   4      p75                                 0.330      0.463
#   5      after_reward_cv                     0.463      0.462
#   6      std_time_after_reward               0.352      0.457
#   7      mean_time_after_reward              0.366      0.454
#   8      reward_effect_predictability       -0.453     -0.445
#   9      mean_time                           0.325      0.439
#   10     median                              0.306      0.437
#
# failure_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      reward_effect                       0.276      0.207
#   2      failure_effect                      0.247      0.169
#   3      mean_time_after_failure            -0.252     -0.112
#   4      std_stops                           0.127      0.112
#   5      std_time_after_failure             -0.234     -0.108
#   6      autocorr_lag1                      -0.006     -0.104
#   7      reward_rate                         0.102      0.103
#   8      prop_patches_with_reward            0.102      0.103
#   9      median                             -0.243     -0.092
#   10     early_mean                         -0.216     -0.091
#
# noise_std - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      after_failure_cv                    0.147      0.224
#   2      std_stops                           0.249      0.217
#   3      mean_reward_trial                   0.315      0.199
#   4      mean_time_after_failure             0.025      0.198
#   5      std_time_after_failure              0.038      0.195
#   6      transition_reliability              0.230      0.189
#   7      late_mean                           0.018      0.161
#   8      middle_mean                         0.034      0.157
#   9      max_time                            0.043      0.152
#   10     p25                                 0.019      0.151
#
# ======================================================================
# METHOD 2: MUTUAL INFORMATION
# ======================================================================
#
# drift_rate - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      mean_stops                           0.9933
#   2      n_patches                            0.9932
#   3      stop_rate                            0.9922
#   4      mean_sites_per_patch                 0.9761
#   5      mean_rewards                         0.8134
#   6      mean_local_std                       0.7958
#   7      std_rewards                          0.7954
#   8      after_failure_cv                     0.6621
#   9      mean_time_after_failure              0.6595
#   10     std_time_after_failure               0.6266
#
# reward_bump - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      iqr                                  0.1808
#   2      autocorr_lag1                        0.1607
#   3      p75                                  0.1578
#   4      median                               0.1482
#   5      std_time_after_failure               0.1457
#   6      middle_mean                          0.1402
#   7      after_reward_cv                      0.1318
#   8      after_failure_cv                     0.1307
#   9      mean_time                            0.1304
#   10     std_time                             0.1275
#
# failure_bump - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      median                               0.0783
#   2      mean_time                            0.0737
#   3      std_time_after_failure               0.0723
#   4      max_time                             0.0618
#   5      failure_effect                       0.0598
#   6      mean_time_after_reward               0.0566
#   7      p75                                  0.0538
#   8      std_time                             0.0503
#   9      reward_effect                        0.0496
#   10     prop_patches_with_reward             0.0484
#
# noise_std - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      p25                                  0.1454
#   2      mean_time_after_failure              0.1262
#   3      std_time_after_failure               0.1038
#   4      stop_rate                            0.0917
#   5      p75                                  0.0915
#   6      n_patches                            0.0900
#   7      mean_stops                           0.0890
#   8      median                               0.0839
#   9      reward_rate                          0.0800
#   10     prop_patches_with_reward             0.0791
#
# ======================================================================
# METHOD 3: RANDOM FOREST IMPORTANCE
# ======================================================================
#
# Training Random Forest for drift_rate...
#
# drift_rate - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      std_stops                            0.0875       0.1772
#   2      stop_rate                            0.2137       0.1459
#   3      mean_stops                           0.2159       0.1426
#   4      mean_sites_per_patch                 0.1960       0.1248
#   5      n_patches                            0.1639       0.0874
#   6      std_rewards                          0.0187       0.0208
#   7      mean_local_std                       0.0049       0.0105
#   8      reward_effect_predictability         0.0044       0.0091
#   9      p25                                  0.0048       0.0084
#   10     iqr                                  0.0064       0.0069
#
# Training Random Forest for reward_bump...
#
# reward_bump - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      reward_effect_predictability         0.1613       0.2564
#   2      mean_rewards                         0.1010       0.2256
#   3      iqr                                  0.0792       0.1736
#   4      autocorr_lag1                        0.1238       0.1013
#   5      std_rewards                          0.0516       0.0874
#   6      signal_to_noise                      0.0148       0.0543
#   7      mean_local_std                       0.0329       0.0508
#   8      std_time                             0.0280       0.0495
#   9      failure_effect                       0.0331       0.0484
#   10     p75                                  0.0357       0.0420
#
# Training Random Forest for failure_bump...
#
# failure_bump - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      reward_effect                        0.0605       0.1186
#   2      reward_effect_predictability         0.0762       0.1082
#   3      diff_std                             0.0419       0.0663
#   4      mean_abs_change                      0.0428       0.0615
#   5      transition_reliability               0.0479       0.0530
#   6      late_minus_early                     0.0433       0.0447
#   7      failure_effect                       0.0663       0.0408
#   8      after_failure_cv                     0.0293       0.0405
#   9      mean_rewards                         0.0233       0.0370
#   10     mean_reward_trial                    0.0353       0.0349
#
# Training Random Forest for noise_std...
#
# noise_std - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      mean_time_after_failure              0.2479       0.4190
#   2      failure_effect                       0.0687       0.1461
#   3      after_failure_cv                     0.0440       0.0917
#   4      std_rewards                          0.0274       0.0821
#   5      reward_effect                        0.0431       0.0652
#   6      mean_local_std                       0.0372       0.0502
#   7      mean_reward_trial                    0.0364       0.0501
#   8      signal_to_noise                      0.0254       0.0422
#   9      mean_rewards                         0.0172       0.0324
#   10     transition_reliability               0.0308       0.0323
#
# ======================================================================
# METHOD 4: LASSO SPARSE SELECTION
# ======================================================================
#
# Running LASSO for drift_rate...
#
# drift_rate - LASSO selected 23/37 features
#   Alpha: 0.000545, R²: 0.903
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      mean_stops                           -0.626882
#   2      after_reward_cv                       0.184654
#   3      std_stops                             0.118394
#   4      reward_effect_predictability         -0.088353
#   5      std_rewards                          -0.080333
#   6      mean_sites_per_patch                  0.075708
#   7      early_mean                            0.055421
#   8      diff_std                             -0.044723
#   9      after_failure_cv                     -0.040099
#   10     failure_effect                        0.034348
#
# Running LASSO for reward_bump...
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.872e-01, tolerance: 6.723e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.044e-01, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.978e-01, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.440e+00, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.227e-01, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.956e+00, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.114e-01, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.644e+00, tolerance: 5.006e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e-01, tolerance: 5.103e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.348e-01, tolerance: 5.103e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.212e-01, tolerance: 5.103e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.457e-02, tolerance: 5.054e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.017e-01, tolerance: 5.054e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.997e-01, tolerance: 5.132e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.604e-01, tolerance: 5.132e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.559e-01, tolerance: 5.132e-02
#   model = cd_fast.enet_coordinate_descent_gram(
# reward_bump - LASSO selected 32/37 features
#   Alpha: 0.000268, R²: 0.599
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      after_reward_cv                       0.664210
#   2      std_time                             -0.605475
#   3      std_time_after_failure                0.602218
#   4      mean_rewards                         -0.371436
#   5      median                                0.358983
#   6      reward_effect_predictability         -0.311487
#   7      max_time                             -0.286640
#   8      after_failure_cv                     -0.258303
#   9      reward_effect                         0.227872
#   10     late_mean                             0.183140
#
# Running LASSO for failure_bump...
#
# failure_bump - LASSO selected 23/37 features
#   Alpha: 0.000627, R²: 0.120
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      reward_effect                         0.241511
#   2      after_failure_cv                     -0.208792
#   3      reward_effect_predictability         -0.167381
#   4      max_time                              0.124236
#   5      std_stops                            -0.117814
#   6      mean_rewards                          0.115296
#   7      p25                                  -0.111101
#   8      mean_time_after_reward               -0.104227
#   9      diff_std                              0.089424
#   10     late_minus_early                      0.080973
#
# Running LASSO for noise_std...
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.877e-03, tolerance: 2.766e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.185e-02, tolerance: 2.773e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.653e-03, tolerance: 2.773e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.879e-03, tolerance: 2.730e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.834e-01, tolerance: 3.434e-03
#   model = cd_fast.enet_coordinate_descent(
# noise_std - LASSO selected 29/37 features
#   Alpha: 0.000044, R²: 0.196
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      std_time                             -0.203013
#   2      median                               -0.191641
#   3      late_mean                             0.161245
#   4      middle_mean                           0.139485
#   5      reward_effect                        -0.095361
#   6      iqr                                   0.089883
#   7      max_time                              0.070616
#   8      early_mean                            0.070286
#   9      std_rewards                          -0.068566
#   10     failure_effect                        0.067763
#
# ======================================================================
# METHOD 5: ENSEMBLE RANKING
# ======================================================================
#
# drift_rate - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      mean_stops                            1.8      1      3    0.8
#   2      mean_sites_per_patch                  3.8      1      6    1.8
#   3      n_patches                             5.8      2     13    4.3
#   4      std_rewards                           8.2      5     15    4.0
#   5      mean_local_std                       11.0      6     20    5.5
#   6      stop_rate                            11.5      2     37   14.7
#   7      std_time_after_failure               12.0      7     17    3.8
#   8      early_mean                           12.5      7     16    3.4
#   9      mean_time_after_failure              13.8      5     30    9.6
#   10     late_mean                            14.5      9     22    4.8
#   11     mean_rewards                         14.8      5     28    9.0
#   12     p25                                  15.0      6     33   10.6
#   13     std_stops                            15.5      1     34   14.0
#   14     middle_mean                          15.8     10     24    5.7
#   15     after_reward_cv                      16.2      2     23    8.3
#
# reward_bump - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      std_time                              5.5      2     10    3.6
#   2      after_reward_cv                       6.5      1     13    4.3
#   3      iqr                                   7.5      1     25   10.1
#   4      reward_effect_predictability          7.5      1     15    5.0
#   5      autocorr_lag1                         7.8      2     22    8.3
#   6      median                                9.2      4     18    5.5
#   7      std_time_after_failure               11.5      3     21    7.7
#   8      p75                                  13.5      3     37   13.8
#   9      after_failure_cv                     14.5      8     28    8.2
#   10     middle_mean                          15.2      6     24    6.4
#   11     early_mean                           15.5     12     19    2.5
#   12     std_time_after_reward                16.0      6     34   10.7
#   13     reward_effect                        16.2      9     32    9.2
#   14     late_mean                            17.0     10     28    6.7
#   15     max_time                             17.8      7     30    9.2
#
# failure_bump - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      reward_effect                         3.0      1      9    3.5
#   2      median                               12.5      1     25    8.8
#   3      max_time                             12.8      4     26    9.3
#   4      failure_effect                       12.8      2     37   14.1
#   5      mean_rewards                         14.8      6     22    7.3
#   6      mean_time_after_failure              14.8      3     28    9.0
#   7      p25                                  14.8      7     20    5.0
#   8      std_time_after_failure               15.2      3     30   11.5
#   9      middle_mean                          15.8     12     21    3.3
#   10     reward_effect_predictability         16.0      2     31   13.5
#   11     late_minus_early                     16.2      6     30    9.2
#   12     mean_time_after_reward               16.5      6     34   11.1
#   13     early_mean                           16.5     10     24    5.0
#   14     iqr                                  16.8     11     33    9.4
#   15     std_stops                            17.2      4     36   13.4
#
# noise_std - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      after_failure_cv                      7.0      1     12    5.0
#   2      std_time_after_failure                8.5      3     15    4.8
#   3      mean_time_after_failure              10.2      1     34   13.8
#   4      std_stops                            10.8      2     15    5.2
#   5      late_mean                            11.8      3     24    7.9
#   6      std_rewards                          12.2      4     19    6.1
#   7      mean_reward_trial                    12.2      3     23    7.8
#   8      failure_effect                       12.2      2     26    8.7
#   9      middle_mean                          14.8      4     24    8.9
#   10     transition_reliability               15.5      6     28    8.4
#   11     p25                                  15.8      1     35   12.5
#   12     mean_local_std                       16.0      6     25    7.0
#   13     median                               16.2      2     28   11.5
#   14     max_time                             16.8      7     34   10.6
#   15     iqr                                  17.0      6     29    9.0
#
# ======================================================================
# GENERATING VISUALIZATIONS
# ======================================================================
# ✓ Saved: feature_importance_heatmap.png
# ✓ Saved: top_features_scatter.png
#
# ======================================================================
# FEATURE SELECTION RECOMMENDATIONS
# ======================================================================
#
# Features appearing in top 10 for multiple parameters:
#   std_time_after_failure         → 4 parameters: drift_rate, reward_bump, failure_bump, noise_std
#   mean_time_after_failure        → 3 parameters: drift_rate, failure_bump, noise_std
#   middle_mean                    → 3 parameters: reward_bump, failure_bump, noise_std
#   std_rewards                    → 2 parameters: drift_rate, noise_std
#   late_mean                      → 2 parameters: drift_rate, noise_std
#   median                         → 2 parameters: reward_bump, failure_bump
#   after_failure_cv               → 2 parameters: reward_bump, noise_std
#   reward_effect_predictability   → 2 parameters: reward_bump, failure_bump
#   failure_effect                 → 2 parameters: failure_bump, noise_std
#   max_time                       → 1 parameters: failure_bump
#   std_time                       → 1 parameters: reward_bump
#   mean_stops                     → 1 parameters: drift_rate
#   std_stops                      → 1 parameters: noise_std
#   mean_rewards                   → 1 parameters: failure_bump
#   early_mean                     → 1 parameters: drift_rate
#   p25                            → 1 parameters: failure_bump
#   p75                            → 1 parameters: reward_bump
#   iqr                            → 1 parameters: reward_bump
#   autocorr_lag1                  → 1 parameters: reward_bump
#   mean_reward_trial              → 1 parameters: noise_std
#   n_patches                      → 1 parameters: drift_rate
#   mean_sites_per_patch           → 1 parameters: drift_rate
#   stop_rate                      → 1 parameters: drift_rate
#   after_reward_cv                → 1 parameters: reward_bump
#   transition_reliability         → 1 parameters: noise_std
#   mean_local_std                 → 1 parameters: drift_rate
#   reward_effect                  → 1 parameters: failure_bump
#
# ======================================================================
# RECOMMENDED MINIMAL FEATURE SETS
# ======================================================================
#
# Top 10 features (union across all parameters):
#   Total: 10 features
#     std_time_after_failure         → drift_rate, reward_bump, failure_bump, noise_std
#     mean_time_after_failure        → drift_rate, failure_bump, noise_std
#     after_failure_cv               → reward_bump, noise_std
#     std_rewards                    → drift_rate, noise_std
#     late_mean                      → drift_rate, noise_std
#     reward_effect_predictability   → reward_bump, failure_bump
#     failure_effect                 → failure_bump, noise_std
#     median                         → reward_bump, failure_bump
#     reward_effect                  → failure_bump
#     mean_local_std                 → drift_rate
#
# Top 15 features (union across all parameters):
#   Total: 15 features
#     std_time_after_failure         → drift_rate, reward_bump, failure_bump, noise_std
#     mean_time_after_failure        → drift_rate, failure_bump, noise_std
#     after_failure_cv               → reward_bump, noise_std
#     std_rewards                    → drift_rate, noise_std
#     late_mean                      → drift_rate, noise_std
#     reward_effect_predictability   → reward_bump, failure_bump
#     failure_effect                 → failure_bump, noise_std
#     median                         → reward_bump, failure_bump
#     mean_reward_trial              → noise_std
#     reward_effect                  → failure_bump
#     mean_local_std                 → drift_rate
#     n_patches                      → drift_rate
#     autocorr_lag1                  → reward_bump
#     mean_rewards                   → failure_bump
#     after_reward_cv                → reward_bump
#
# Top 20 features (union across all parameters):
#   Total: 20 features
#     std_time_after_failure         → drift_rate, reward_bump, failure_bump, noise_std
#     mean_time_after_failure        → drift_rate, failure_bump, noise_std
#     middle_mean                    → reward_bump, failure_bump, noise_std
#     after_failure_cv               → reward_bump, noise_std
#     std_rewards                    → drift_rate, noise_std
#     late_mean                      → drift_rate, noise_std
#     reward_effect_predictability   → reward_bump, failure_bump
#     failure_effect                 → failure_bump, noise_std
#     median                         → reward_bump, failure_bump
#     mean_reward_trial              → noise_std
#     reward_effect                  → failure_bump
#     mean_local_std                 → drift_rate
#     n_patches                      → drift_rate
#     autocorr_lag1                  → reward_bump
#     mean_rewards                   → failure_bump
#     after_reward_cv                → reward_bump
#     early_mean                     → drift_rate
#     p25                            → failure_bump
#     p75                            → reward_bump
#     transition_reliability         → noise_std

# %%
# For 23-feature model
from aind_behavior_vrforaging_analysis.sbi_ddm_analysis.enhanced_stats_23 import FEATURE_NAMES  # 23 features

# Initialize simulator
simulator_23 = PatchForagingDDM_JAX(max_sites_per_window=100)
prior_fn = create_prior()

results_23 = comprehensive_feature_importance_analysis(
    simulator_23,  # Your 23-feature simulator
    prior_fn,
    FEATURE_NAMES,
    n_samples=2000
)
# Out:
# ======================================================================
# COMPREHENSIVE FEATURE IMPORTANCE ANALYSIS
# ======================================================================
#
# Generating 2000 samples from prior...
#   0/2000...
#   200/2000...
#   400/2000...
#   600/2000...
#   800/2000...
#   1000/2000...
#   1200/2000...
#   1400/2000...
#   1600/2000...
#   1800/2000...
#
# ✓ Generated data shape: thetas=(2000, 4), stats=(2000, 23)
#
# ======================================================================
# METHOD 1: CORRELATION ANALYSIS
# ======================================================================
#
# drift_rate - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      stop_rate                          -0.935     -0.929
#   2      mean_sites_per_patch               -0.462     -0.929
#   3      early_mean                         -0.646     -0.824
#   4      mean_time_after_reward             -0.616     -0.813
#   5      after_reward_cv                    -0.780     -0.783
#   6      iqr                                -0.536     -0.782
#   7      diff_std                           -0.790     -0.778
#   8      transition_reliability              0.672      0.778
#   9      autocorr_lag1                      -0.713     -0.723
#   10     mean_abs_change                    -0.644     -0.706
#
# reward_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      local_deviation                    -0.494     -0.552
#   2      autocorr_lag2                       0.538      0.530
#   3      iqr                                 0.352      0.482
#   4      autocorr_lag1                       0.302      0.472
#   5      after_reward_cv                     0.463      0.462
#   6      mean_time_after_reward              0.366      0.454
#   7      reward_effect_predictability       -0.453     -0.445
#   8      cv_overall                          0.417      0.435
#   9      early_mean                          0.378      0.401
#   10     mean_abs_change                     0.328      0.335
#
# failure_bump - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      failure_bump_magnitude              0.266      0.201
#   2      autocorr_lag2                      -0.126     -0.125
#   3      local_deviation                     0.106      0.119
#   4      autocorr_lag1                      -0.006     -0.104
#   5      early_mean                         -0.216     -0.091
#   6      iqr                                -0.237     -0.089
#   7      mean_time_after_reward             -0.220     -0.085
#   8      temporal_trend                     -0.100     -0.077
#   9      after_reward_cv                    -0.066     -0.076
#   10     stop_rate                          -0.050     -0.073
#
# noise_std - Top 10 correlated features:
#   Rank   Feature                           Pearson   Spearman
#   ------------------------------------------------------------
#   1      outlier_rate                        0.236      0.233
#   2      after_failure_cv                    0.147      0.224
#   3      mean_reward_trial                   0.315      0.199
#   4      cv_overall                          0.198      0.165
#   5      reward_variability_ratio            0.169      0.145
#   6      diff_std                            0.151      0.142
#   7      transition_reliability             -0.180     -0.142
#   8      mean_abs_change                     0.186      0.137
#   9      early_mean                          0.044      0.129
#   10     stop_rate                           0.103      0.126
#
# ======================================================================
# METHOD 2: MUTUAL INFORMATION
# ======================================================================
#
# drift_rate - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      stop_rate                            1.0019
#   2      mean_sites_per_patch                 0.9916
#   3      after_failure_cv                     0.6626
#   4      early_mean                           0.5937
#   5      iqr                                  0.5102
#   6      mean_time_after_reward               0.5078
#   7      after_reward_cv                      0.4925
#   8      autocorr_lag2                        0.4916
#   9      diff_std                             0.4631
#   10     outlier_rate                         0.4396
#
# reward_bump - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      local_deviation                      0.2323
#   2      autocorr_lag2                        0.1982
#   3      iqr                                  0.1812
#   4      cv_overall                           0.1654
#   5      autocorr_lag1                        0.1615
#   6      after_reward_cv                      0.1310
#   7      after_failure_cv                     0.1308
#   8      reward_effect_predictability         0.1125
#   9      early_mean                           0.1105
#   10     late_minus_early                     0.1093
#
# failure_bump - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      failure_bump_magnitude               0.0747
#   2      mean_sites_per_patch                 0.0638
#   3      mean_time_after_reward               0.0566
#   4      iqr                                  0.0456
#   5      late_minus_early                     0.0400
#   6      stop_rate                            0.0385
#   7      early_mean                           0.0322
#   8      autocorr_lag2                        0.0321
#   9      after_failure_cv                     0.0287
#   10     reward_variability_ratio             0.0278
#
# noise_std - Top 10 by Mutual Information:
#   Rank   Feature                            MI Score
#   --------------------------------------------------
#   1      stop_rate                            0.0862
#   2      iqr                                  0.0778
#   3      after_failure_cv                     0.0759
#   4      mean_reward_trial                    0.0687
#   5      temporal_trend                       0.0620
#   6      mean_sites_per_patch                 0.0594
#   7      failure_bump_magnitude               0.0540
#   8      late_minus_early                     0.0407
#   9      early_mean                           0.0393
#   10     outlier_rate                         0.0378
#
# ======================================================================
# METHOD 3: RANDOM FOREST IMPORTANCE
# ======================================================================
#
# Training Random Forest for drift_rate...
#
# drift_rate - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      mean_sites_per_patch                 0.5215       0.6050
#   2      stop_rate                            0.3686       0.3826
#   3      local_deviation                      0.0504       0.0958
#   4      reward_effect_predictability         0.0037       0.0082
#   5      early_mean                           0.0043       0.0070
#   6      first_trial_time                     0.0051       0.0064
#   7      after_failure_cv                     0.0044       0.0061
#   8      outlier_rate                         0.0036       0.0058
#   9      cv_overall                           0.0032       0.0052
#   10     mean_abs_change                      0.0030       0.0051
#
# Training Random Forest for reward_bump...
#
# reward_bump - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      local_deviation                      0.2372       0.5785
#   2      autocorr_lag2                        0.3117       0.2318
#   3      reward_effect_predictability         0.0663       0.1911
#   4      iqr                                  0.0776       0.1701
#   5      cv_overall                           0.0310       0.0496
#   6      failure_bump_magnitude               0.0353       0.0484
#   7      first_trial_time                     0.0324       0.0356
#   8      signal_to_noise                      0.0219       0.0346
#   9      after_failure_cv                     0.0181       0.0327
#   10     early_mean                           0.0213       0.0281
#
# Training Random Forest for failure_bump...
#
# failure_bump - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      failure_bump_magnitude               0.1059       0.1339
#   2      reward_effect_predictability         0.0805       0.1232
#   3      local_deviation                      0.0706       0.0994
#   4      mean_abs_change                      0.0495       0.0730
#   5      after_failure_cv                     0.0415       0.0643
#   6      reward_variability_ratio             0.0398       0.0555
#   7      iqr                                  0.0935       0.0507
#   8      late_minus_early                     0.0472       0.0483
#   9      autocorr_lag2                        0.0403       0.0418
#   10     first_trial_time                     0.0516       0.0392
#
# Training Random Forest for noise_std...
#
# noise_std - Top 10 by Random Forest:
#   Rank   Feature                          Importance     Perm.Imp
#   --------------------------------------------------------------
#   1      after_failure_cv                     0.2509       0.4284
#   2      local_deviation                      0.1142       0.1623
#   3      mean_sites_per_patch                 0.0414       0.1248
#   4      stop_rate                            0.0389       0.1246
#   5      failure_bump_magnitude               0.0453       0.1122
#   6      signal_to_noise                      0.0458       0.0821
#   7      iqr                                  0.0377       0.0804
#   8      mean_reward_trial                    0.0735       0.0590
#   9      late_minus_early                     0.0290       0.0386
#   10     reward_effect_predictability         0.0250       0.0379
#
# ======================================================================
# METHOD 4: LASSO SPARSE SELECTION
# ======================================================================
#
# Running LASSO for drift_rate...
#
# drift_rate - LASSO selected 18/23 features
#   Alpha: 0.000545, R²: 0.906
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      stop_rate                            -0.576601
#   2      local_deviation                      -0.078460
#   3      after_reward_cv                       0.073061
#   4      mean_sites_per_patch                 -0.059933
#   5      reward_effect_predictability         -0.049501
#   6      mean_reward_trial                     0.025982
#   7      diff_std                             -0.020402
#   8      mean_abs_change                      -0.018761
#   9      late_minus_early                      0.016316
#   10     early_mean                            0.014706
#
# Running LASSO for reward_bump...
#
# reward_bump - LASSO selected 20/23 features
#   Alpha: 0.000545, R²: 0.597
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      after_reward_cv                       0.614574
#   2      stop_rate                            -0.457779
#   3      reward_effect_predictability         -0.287451
#   4      after_failure_cv                     -0.194952
#   5      reward_variability_ratio             -0.190427
#   6      mean_abs_change                       0.128383
#   7      local_deviation                      -0.127437
#   8      mean_time_after_reward                0.116282
#   9      mean_sites_per_patch                 -0.103866
#   10     failure_bump_magnitude                0.089131
#
# Running LASSO for failure_bump...
#
# failure_bump - LASSO selected 23/23 features
#   Alpha: 0.000150, R²: 0.112
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      iqr                                   0.356631
#   2      failure_bump_magnitude                0.353713
#   3      mean_time_after_reward               -0.352682
#   4      after_failure_cv                     -0.192677
#   5      reward_effect_predictability         -0.167176
#   6      mean_sites_per_patch                  0.132073
#   7      autocorr_lag1                        -0.117353
#   8      diff_std                              0.086250
#   9      transition_reliability                0.081934
#   10     reward_variability_ratio              0.072598
#
# Running LASSO for noise_std...
#
# noise_std - LASSO selected 22/23 features
#   Alpha: 0.000089, R²: 0.174
#
#   Rank   Feature                            Coefficient
#   -----------------------------------------------------
#   1      mean_time_after_reward                0.111393
#   2      failure_bump_magnitude               -0.107755
#   3      iqr                                  -0.106979
#   4      after_reward_cv                      -0.081019
#   5      mean_sites_per_patch                 -0.064682
#   6      cv_overall                            0.044852
#   7      after_failure_cv                      0.039590
#   8      reward_variability_ratio              0.037265
#   9      mean_reward_trial                     0.030371
#   10     reward_effect_predictability          0.025941
#
# ======================================================================
# METHOD 5: ENSEMBLE RANKING
# ======================================================================
#
# drift_rate - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      stop_rate                             1.2      1      2    0.4
#   2      mean_sites_per_patch                  2.2      1      4    1.1
#   3      early_mean                            5.5      3     10    2.7
#   4      after_reward_cv                       8.2      3     18    5.8
#   5      after_failure_cv                      8.2      3     12    3.6
#   6      reward_effect_predictability         10.0      4     17    5.6
#   7      mean_abs_change                      10.2      8     13    1.8
#   8      local_deviation                      10.2      2     20    7.9
#   9      iqr                                  10.5      5     20    5.9
#   10     diff_std                             11.5      7     23    6.7
#   11     mean_reward_trial                    12.2      6     18    4.3
#   12     mean_time_after_reward               12.5      4     21    7.6
#   13     outlier_rate                         13.5      8     20    4.8
#   14     autocorr_lag1                        13.8      9     19    4.0
#   15     cv_overall                           15.0      9     23    5.1
#
# reward_bump - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      local_deviation                       2.5      1      7    2.6
#   2      reward_effect_predictability          5.2      3      8    2.3
#   3      iqr                                   6.5      3     16    5.5
#   4      after_reward_cv                       6.5      1     14    4.7
#   5      autocorr_lag2                         7.2      2     23    9.1
#   6      cv_overall                            7.8      4     14    3.9
#   7      after_failure_cv                      9.2      4     17    4.8
#   8      mean_time_after_reward               10.0      6     15    3.4
#   9      early_mean                           10.2      9     13    1.6
#   10     autocorr_lag1                        11.2      4     18    6.8
#   11     mean_abs_change                      11.5      6     16    3.8
#   12     reward_variability_ratio             11.5      5     16    4.0
#   13     failure_bump_magnitude               11.8      6     19    4.7
#   14     stop_rate                            12.5      2     19    6.3
#   15     signal_to_noise                      14.5      8     22    5.0
#
# failure_bump - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      failure_bump_magnitude                1.2      1      2    0.4
#   2      iqr                                   4.5      1      7    2.3
#   3      autocorr_lag2                         8.5      2     15    4.6
#   4      mean_time_after_reward                9.0      3     23    8.2
#   5      after_failure_cv                      9.0      4     18    5.5
#   6      reward_effect_predictability          9.0      2     15    5.6
#   7      early_mean                           10.0      5     16    4.3
#   8      late_minus_early                     10.2      5     14    3.9
#   9      mean_sites_per_patch                 10.2      2     22    7.5
#   10     reward_variability_ratio             10.8      6     17    4.0
#   11     local_deviation                      11.0      3     20    8.0
#   12     autocorr_lag1                        11.2      4     17    5.8
#   13     stop_rate                            13.0      6     20    5.4
#   14     after_reward_cv                      13.0      9     21    4.7
#   15     mean_reward_trial                    14.5     11     20    3.5
#
# noise_std - ENSEMBLE RANKING (lower rank = more important):
#   Rank   Feature                          Avg Rank   Best  Worst    Std
#   ----------------------------------------------------------------------
#   1      after_failure_cv                      3.2      1      7    2.3
#   2      mean_reward_trial                     6.0      3      9    2.5
#   3      mean_sites_per_patch                  6.2      3     11    2.9
#   4      iqr                                   6.8      2     15    5.1
#   5      stop_rate                             6.8      1     12    4.4
#   6      failure_bump_magnitude                8.8      2     21    7.3
#   7      reward_variability_ratio              9.5      5     14    3.4
#   8      cv_overall                           10.2      4     19    5.8
#   9      early_mean                           11.5      9     16    2.9
#   10     mean_time_after_reward               11.5      1     20    6.8
#   11     signal_to_noise                      11.5      6     14    3.2
#   12     outlier_rate                         11.5      1     18    6.8
#   13     late_minus_early                     13.2      8     19    4.8
#   14     reward_effect_predictability         14.0     10     18    4.0
#   15     local_deviation                      14.0      2     23    7.6
#
# ======================================================================
# GENERATING VISUALIZATIONS
# ======================================================================
# ✓ Saved: feature_importance_heatmap.png
# ✓ Saved: top_features_scatter.png
#
# ======================================================================
# FEATURE SELECTION RECOMMENDATIONS
# ======================================================================
#
# Features appearing in top 10 for multiple parameters:
#   iqr                            → 4 parameters: drift_rate, reward_bump, failure_bump, noise_std
#   early_mean                     → 4 parameters: drift_rate, reward_bump, failure_bump, noise_std
#   after_failure_cv               → 4 parameters: drift_rate, reward_bump, failure_bump, noise_std
#   mean_time_after_reward         → 3 parameters: reward_bump, failure_bump, noise_std
#   reward_effect_predictability   → 3 parameters: drift_rate, reward_bump, failure_bump
#   mean_sites_per_patch           → 3 parameters: drift_rate, failure_bump, noise_std
#   stop_rate                      → 2 parameters: drift_rate, noise_std
#   after_reward_cv                → 2 parameters: drift_rate, reward_bump
#   reward_variability_ratio       → 2 parameters: failure_bump, noise_std
#   local_deviation                → 2 parameters: drift_rate, reward_bump
#   cv_overall                     → 2 parameters: reward_bump, noise_std
#   autocorr_lag2                  → 2 parameters: reward_bump, failure_bump
#   failure_bump_magnitude         → 2 parameters: failure_bump, noise_std
#   autocorr_lag1                  → 1 parameters: reward_bump
#   diff_std                       → 1 parameters: drift_rate
#   mean_abs_change                → 1 parameters: drift_rate
#   late_minus_early               → 1 parameters: failure_bump
#   mean_reward_trial              → 1 parameters: noise_std
#
# ======================================================================
# RECOMMENDED MINIMAL FEATURE SETS
# ======================================================================
#
# Top 10 features (union across all parameters):
#   Total: 10 features
#     early_mean                     → drift_rate, reward_bump, failure_bump, noise_std
#     iqr                            → drift_rate, reward_bump, failure_bump, noise_std
#     after_failure_cv               → drift_rate, reward_bump, failure_bump, noise_std
#     mean_sites_per_patch           → drift_rate, failure_bump, noise_std
#     reward_effect_predictability   → drift_rate, reward_bump, failure_bump
#     mean_time_after_reward         → reward_bump, failure_bump, noise_std
#     after_reward_cv                → drift_rate, reward_bump
#     local_deviation                → drift_rate, reward_bump
#     stop_rate                      → drift_rate, noise_std
#     autocorr_lag2                  → reward_bump, failure_bump
#
# Top 15 features (union across all parameters):
#   Total: 15 features
#     early_mean                     → drift_rate, reward_bump, failure_bump, noise_std
#     iqr                            → drift_rate, reward_bump, failure_bump, noise_std
#     after_failure_cv               → drift_rate, reward_bump, failure_bump, noise_std
#     mean_sites_per_patch           → drift_rate, failure_bump, noise_std
#     reward_effect_predictability   → drift_rate, reward_bump, failure_bump
#     mean_time_after_reward         → reward_bump, failure_bump, noise_std
#     cv_overall                     → reward_bump, noise_std
#     after_reward_cv                → drift_rate, reward_bump
#     reward_variability_ratio       → failure_bump, noise_std
#     local_deviation                → drift_rate, reward_bump
#     stop_rate                      → drift_rate, noise_std
#     autocorr_lag2                  → reward_bump, failure_bump
#     failure_bump_magnitude         → failure_bump, noise_std
#     mean_abs_change                → drift_rate
#     mean_reward_trial              → noise_std
#
# Top 20 features (union across all parameters):
#   Total: 18 features
#     early_mean                     → drift_rate, reward_bump, failure_bump, noise_std
#     iqr                            → drift_rate, reward_bump, failure_bump, noise_std
#     after_failure_cv               → drift_rate, reward_bump, failure_bump, noise_std
#     mean_sites_per_patch           → drift_rate, failure_bump, noise_std
#     reward_effect_predictability   → drift_rate, reward_bump, failure_bump
#     mean_time_after_reward         → reward_bump, failure_bump, noise_std
#     cv_overall                     → reward_bump, noise_std
#     after_reward_cv                → drift_rate, reward_bump
#     reward_variability_ratio       → failure_bump, noise_std
#     local_deviation                → drift_rate, reward_bump
#     stop_rate                      → drift_rate, noise_std
#     autocorr_lag2                  → reward_bump, failure_bump
#     failure_bump_magnitude         → failure_bump, noise_std
#     mean_abs_change                → drift_rate
#     diff_std                       → drift_rate
#     late_minus_early               → failure_bump
#     mean_reward_trial              → noise_std
#     autocorr_lag1                  → reward_bump

# %%
from aind_behavior_vrforaging_analysis.sbi_ddm_analysis.enhanced_stats import compute_summary_stats

# Test sensitivity of new features
def test_new_features():
    rng_key = random.PRNGKey(42)
    
    test_cases = {
        'High drift vs low drift': [
            jnp.array([1.5, 0.5, 0.5, 0.2]),
            jnp.array([0.3, 0.5, 0.5, 0.2]),
        ],
        'High reward_bump vs low': [
            jnp.array([0.75, 1.5, 0.5, 0.2]),
            jnp.array([0.75, 0.2, 0.5, 0.2]),
        ],
        'High failure_bump vs low': [
            jnp.array([0.75, 0.5, 1.5, 0.2]),
            jnp.array([0.75, 0.5, 0.2, 0.2]),
        ],
        'High noise vs low': [
            jnp.array([0.75, 0.5, 0.5, 0.4]),
            jnp.array([0.75, 0.5, 0.5, 0.05]),
        ],
    }
    
    for test_name, (theta1, theta2) in test_cases.items():
        print(f"\n{test_name}:")
        
        # Simulate from each
        stats1_list = []
        stats2_list = []
        
        for _ in range(50):
            rng_key, sub1, sub2 = random.split(rng_key, 3)
            
            window_data1, _, _ = simulate_and_extract(theta1, sub1)
            stats1 = compute_summary_stats(window_data1)
            stats1_list.append(stats1)
            
            window_data2, _, _ = simulate_and_extract(theta2, sub2)
            stats2 = compute_summary_stats(window_data2)
            stats2_list.append(stats2)
        
        stats1_mean = jnp.mean(jnp.array(stats1_list), axis=0)
        stats2_mean = jnp.mean(jnp.array(stats2_list), axis=0)
        
        # Find features with biggest difference
        diffs = jnp.abs(stats1_mean - stats2_mean)
        top_5 = jnp.argsort(diffs)[::-1][:5]
        
        print("  Top 5 discriminating features:")
        for rank, idx in enumerate(top_5, 1):
            print(f"    {rank}. {OPTIMIZED_FEATURE_NAMES[idx]:<30} "
                  f"({stats1_mean[idx]:.3f} vs {stats2_mean[idx]:.3f})")

test_new_features()
# Out:
# High drift vs low drift:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Cell In[3], line 56
#      52         for rank, idx in enumerate(top_5, 1):
#      53             print(f"    {rank}. {OPTIMIZED_FEATURE_NAMES[idx]:<30} "
#      54                   f"({stats1_mean[idx]:.3f} vs {stats2_mean[idx]:.3f})")
# ---> 56 test_new_features()
#
# Cell In[3], line 36, in test_new_features()
#      33 for _ in range(50):
#      34     rng_key, sub1, sub2 = random.split(rng_key, 3)
# ---> 36     window_data1, _, _ = simulate_and_extract(theta1, sub1)
#      37     stats1 = compute_summary_stats(window_data1)
#      38     stats1_list.append(stats1)
#
# Cell In[1], line 62, in simulate_and_extract(theta, rng_key, window_sites)
#      57 """
#      58 Runs one simulation for given theta and extracts features.
#      59 Returns (window_data, summary_stats, new_rng_key)
#      60 """
#      61 rng_key, subkey = random.split(rng_key)
# ---> 62 window_data, summary_stats = simulator.simulate_one_window(theta, subkey)
#      63 return window_data, summary_stats, rng_key
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:219, in PatchForagingDDM_JAX.simulate_one_window(self, theta, rng_key)
#     207 """
#     208 Simulate one window (user-facing API).
#     209
#    (...)    216     summary_stats: (37,) array of summary statistics
#     217 """
#     218 theta = jnp.array(theta)
# --> 219 window_data, summary_stats = self._simulate_one_window_jit(theta, rng_key)
#     221 return window_data, summary_stats
#
#     [... skipping hidden 13 frame]
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:197, in PatchForagingDDM_JAX._simulate_one_window_core(self, theta, rng_key)
#     194 def multi_patch_case(_):
#     195     return compute_enhanced_summary_stats(window_data)
# --> 197 summary_stats = jax.lax.cond(
#     198     num_stops < 2,
#     199     single_patch_case,
#     200     multi_patch_case,
#     201     operand=None
#     202 )
#     204 return window_data, summary_stats
#
#     [... skipping hidden 11 frame]
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:195, in PatchForagingDDM_JAX._simulate_one_window_core.<locals>.multi_patch_case(_)
#     194 def multi_patch_case(_):
# --> 195     return compute_enhanced_summary_stats(window_data)
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:366, in compute_enhanced_summary_stats(window_data)
#     360 warnings.warn("compute_enhanced_summary_stats has 37 redundant features. "
#     361               "Consider using compute_optimized_summary_stats with 31 features.",
#     362               DeprecationWarning)
#     364 # You can keep the original implementation or just return extended version
#     365 # For now, let's just call optimized and pad with zeros for missing features
# --> 366 return compute_summary_stats(window_data)
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:181, in compute_summary_stats(window_data)
#     178 stats.append(first_trial_time)  # first_trial_time
#     180 # 2. Effect of FIRST reward
# --> 181 first_reward_indices = jnp.where((rewards > 0) & valid_mask)[0]
#     182 first_reward_idx = jnp.where(len(first_reward_indices) > 0, first_reward_indices[0], -1)
#     184 # Check if we have a valid first reward and a trial after it
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:2772, in where(condition, x, y, size, fill_value)
#    2770 if x is None and y is None:
#    2771   util.check_arraylike("where", condition)
# -> 2772   return nonzero(condition, size=size, fill_value=fill_value)
#    2773 else:
#    2774   util.check_arraylike("where", condition, x, y)
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:3709, in nonzero(***failed resolving arguments***)
#    3707 mask = arr if arr.dtype == bool else (arr != 0)
#    3708 calculated_size_ = mask.sum() if size is None else size
# -> 3709 calculated_size: int = core.concrete_dim_or_error(calculated_size_,
#    3710   "The size argument of jnp.nonzero must be statically specified "
#    3711   "to use jnp.nonzero within JAX transformations.")
#    3712 if arr.size == 0 or calculated_size == 0:
#    3713   return tuple(array_creation.zeros(calculated_size, int) for dim in arr.shape)
#
#     [... skipping hidden 1 frame]
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/core.py:1821, in concrete_or_error(force, val, context)
#    1819 maybe_concrete = val.to_concrete_value()
#    1820 if maybe_concrete is None:
# -> 1821   raise ConcretizationTypeError(val, context)
#    1822 else:
#    1823   return force(maybe_concrete)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: traced array with shape int32[]
# The size argument of jnp.nonzero must be statically specified to use jnp.nonzero within JAX transformations.
# The error occurred while tracing the function multi_patch_case at /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:194 for cond. This value became a tracer due to JAX operations on these lines:
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 1) start_indices=(0, 0) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:61:18 (compute_summary_stats)
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 2) start_indices=(0, 1) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:62:14 (compute_summary_stats)
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 3) start_indices=(0, 2) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:63:12 (compute_summary_stats)
#
#   operation a:bool[100] = gt b 0.0:f32[]
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:66:17 (compute_summary_stats)
#
#   operation c:f32[100] = jit[
#   name=_where
#   jaxpr={ lambda ; a:bool[100] b:f32[100] d:f32[]. let
#       e:f32[] = convert_element_type[new_dtype=float32 weak_type=False] d
#       f:f32[100] = broadcast_in_dim[
#         broadcast_dimensions=()
#         shape=(100,)
#         sharding=None
#       ] e
#       c:f32[100] = select_n a f b
#     in (c,) }
# ] a b inf:f32[]
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:78:18 (compute_summary_stats)
#
# (Additional originating lines are not shown.)
#
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.ConcretizationTypeError

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

def analyze_summary_stat_correlations(n_samples=1000):
    """
    Generate samples from prior, compute correlations, visualize redundancy
    """
    print("Generating samples from prior...")
    rng_key = random.PRNGKey(42)
    prior_fn = create_prior()
    
    # Sample from prior
    prior_dist = prior_fn()
    theta_samples = prior_dist.sample(n_samples, seed=rng_key)['theta']
    
    # Simulate and extract stats
    all_stats = []
    for i in range(n_samples):
        rng_key, subkey = random.split(rng_key)
        _, stats, _ = simulate_and_extract(theta_samples[i], subkey)
        all_stats.append(stats)
    
    all_stats = np.array(all_stats)  # (1000, 37)
    
    # Compute correlation matrix
    corr_matrix = np.corrcoef(all_stats.T)
    
    # === PLOT 1: Full correlation heatmap ===
    fig, ax = plt.subplots(figsize=(16, 14))
    im = ax.imshow(corr_matrix, cmap='RdBu_r', vmin=-1, vmax=1, aspect='auto')
    
    # Add feature names
    ax.set_xticks(range(len(FEATURE_NAMES)))
    ax.set_yticks(range(len(FEATURE_NAMES)))
    ax.set_xticklabels(FEATURE_NAMES, rotation=90, ha='right', fontsize=8)
    ax.set_yticklabels(FEATURE_NAMES, fontsize=8)
    
    # Add colorbar
    plt.colorbar(im, ax=ax, label='Correlation')
    
    # Add grid lines between groups
    group_boundaries = [0, 7, 11, 16, 20, 23, 26, 37]
    for boundary in group_boundaries:
        ax.axhline(boundary - 0.5, color='black', linewidth=1.5)
        ax.axvline(boundary - 0.5, color='black', linewidth=1.5)
    
    plt.title('Summary Statistics Correlation Matrix', fontsize=14, pad=20)
    plt.tight_layout()
    plt.savefig('correlation_matrix_full.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    # === PLOT 2: Hierarchical clustering to find redundant groups ===
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Convert correlation to distance
    distance_matrix = 1 - np.abs(corr_matrix)
    linkage_matrix = linkage(distance_matrix, method='ward')
    
    dendrogram(linkage_matrix, labels=FEATURE_NAMES, ax=ax, 
               orientation='right', leaf_font_size=8)
    ax.set_xlabel('Distance (1 - |correlation|)')
    ax.set_title('Hierarchical Clustering of Summary Statistics')
    plt.tight_layout()
    plt.savefig('stat_clustering.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    # === IDENTIFY HIGHLY CORRELATED PAIRS ===
    print("\n" + "="*70)
    print("HIGHLY CORRELATED PAIRS (|r| > 0.95)")
    print("="*70)
    
    high_corr_pairs = []
    for i in range(len(FEATURE_NAMES)):
        for j in range(i+1, len(FEATURE_NAMES)):
            if abs(corr_matrix[i, j]) > 0.95:
                high_corr_pairs.append((i, j, corr_matrix[i, j]))
    
    high_corr_pairs.sort(key=lambda x: abs(x[2]), reverse=True)
    
    for i, j, r in high_corr_pairs:
        print(f"{FEATURE_NAMES[i]:<30} <-> {FEATURE_NAMES[j]:<30}  r = {r:>6.3f}")
    
    print(f"\nTotal highly correlated pairs: {len(high_corr_pairs)}")
    
    # === RECOMMEND REMOVALS ===
    print("\n" + "="*70)
    print("RECOMMENDED REMOVALS (keep one from each pair)")
    print("="*70)
    
    to_remove = set()
    for i, j, r in high_corr_pairs:
        if i not in to_remove and j not in to_remove:
            # Keep the one that appears in fewer pairs
            i_count = sum(1 for x, y, _ in high_corr_pairs if i in (x, y))
            j_count = sum(1 for x, y, _ in high_corr_pairs if j in (x, y))
            
            if j_count > i_count:
                to_remove.add(j)
                print(f"Remove: {FEATURE_NAMES[j]:<30} (redundant with {FEATURE_NAMES[i]})")
            else:
                to_remove.add(i)
                print(f"Remove: {FEATURE_NAMES[i]:<30} (redundant with {FEATURE_NAMES[j]})")
    
    print(f"\nRecommended to remove: {len(to_remove)} stats")
    print(f"Would reduce from {len(FEATURE_NAMES)} -> {len(FEATURE_NAMES) - len(to_remove)} stats")
    
    return all_stats, corr_matrix, list(to_remove)

# Run the analysis
all_stats, corr_matrix, to_remove = analyze_summary_stat_correlations(n_samples=1000)
# Out:
# Generating samples from prior...
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Cell In[5], line 109
#     106     return all_stats, corr_matrix, list(to_remove)
#     108 # Run the analysis
# --> 109 all_stats, corr_matrix, to_remove = analyze_summary_stat_correlations(n_samples=1000)
#
# Cell In[5], line 19, in analyze_summary_stat_correlations(n_samples)
#      17 for i in range(n_samples):
#      18     rng_key, subkey = random.split(rng_key)
# ---> 19     _, stats, _ = simulate_and_extract(theta_samples[i], subkey)
#      20     all_stats.append(stats)
#      22 all_stats = np.array(all_stats)  # (1000, 37)
#
# Cell In[4], line 62, in simulate_and_extract(theta, rng_key, window_sites)
#      57 """
#      58 Runs one simulation for given theta and extracts features.
#      59 Returns (window_data, summary_stats, new_rng_key)
#      60 """
#      61 rng_key, subkey = random.split(rng_key)
# ---> 62 window_data, summary_stats = simulator.simulate_one_window(theta, subkey)
#      63 return window_data, summary_stats, rng_key
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:219, in PatchForagingDDM_JAX.simulate_one_window(self, theta, rng_key)
#     207 """
#     208 Simulate one window (user-facing API).
#     209
#    (...)    216     summary_stats: (37,) array of summary statistics
#     217 """
#     218 theta = jnp.array(theta)
# --> 219 window_data, summary_stats = self._simulate_one_window_jit(theta, rng_key)
#     221 return window_data, summary_stats
#
#     [... skipping hidden 13 frame]
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:197, in PatchForagingDDM_JAX._simulate_one_window_core(self, theta, rng_key)
#     194 def multi_patch_case(_):
#     195     return compute_enhanced_summary_stats(window_data)
# --> 197 summary_stats = jax.lax.cond(
#     198     num_stops < 2,
#     199     single_patch_case,
#     200     multi_patch_case,
#     201     operand=None
#     202 )
#     204 return window_data, summary_stats
#
#     [... skipping hidden 11 frame]
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:195, in PatchForagingDDM_JAX._simulate_one_window_core.<locals>.multi_patch_case(_)
#     194 def multi_patch_case(_):
# --> 195     return compute_enhanced_summary_stats(window_data)
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:366, in compute_enhanced_summary_stats(window_data)
#     360 warnings.warn("compute_enhanced_summary_stats has 37 redundant features. "
#     361               "Consider using compute_optimized_summary_stats with 31 features.",
#     362               DeprecationWarning)
#     364 # You can keep the original implementation or just return extended version
#     365 # For now, let's just call optimized and pad with zeros for missing features
# --> 366 return compute_optimized_summary_stats(window_data)
#
# File ~/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:181, in compute_optimized_summary_stats(window_data)
#     178 stats.append(first_trial_time)  # first_trial_time
#     180 # 2. Effect of FIRST reward
# --> 181 first_reward_indices = jnp.where((rewards > 0) & valid_mask)[0]
#     182 first_reward_idx = jnp.where(len(first_reward_indices) > 0, first_reward_indices[0], -1)
#     184 # Check if we have a valid first reward and a trial after it
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:2772, in where(condition, x, y, size, fill_value)
#    2770 if x is None and y is None:
#    2771   util.check_arraylike("where", condition)
# -> 2772   return nonzero(condition, size=size, fill_value=fill_value)
#    2773 else:
#    2774   util.check_arraylike("where", condition, x, y)
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:3709, in nonzero(***failed resolving arguments***)
#    3707 mask = arr if arr.dtype == bool else (arr != 0)
#    3708 calculated_size_ = mask.sum() if size is None else size
# -> 3709 calculated_size: int = core.concrete_dim_or_error(calculated_size_,
#    3710   "The size argument of jnp.nonzero must be statically specified "
#    3711   "to use jnp.nonzero within JAX transformations.")
#    3712 if arr.size == 0 or calculated_size == 0:
#    3713   return tuple(array_creation.zeros(calculated_size, int) for dim in arr.shape)
#
#     [... skipping hidden 1 frame]
#
# File /opt/miniconda3/envs/sbi_jax_py311/lib/python3.11/site-packages/jax/_src/core.py:1821, in concrete_or_error(force, val, context)
#    1819 maybe_concrete = val.to_concrete_value()
#    1820 if maybe_concrete is None:
# -> 1821   raise ConcretizationTypeError(val, context)
#    1822 else:
#    1823   return force(maybe_concrete)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: traced array with shape int32[]
# The size argument of jnp.nonzero must be statically specified to use jnp.nonzero within JAX transformations.
# The error occurred while tracing the function multi_patch_case at /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/simulator.py:194 for cond. This value became a tracer due to JAX operations on these lines:
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 1) start_indices=(0, 0) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:61:18 (compute_optimized_summary_stats)
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 2) start_indices=(0, 1) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:62:14 (compute_optimized_summary_stats)
#
#   operation a:f32[100,1] = slice[limit_indices=(100, 3) start_indices=(0, 2) strides=None] b
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:63:12 (compute_optimized_summary_stats)
#
#   operation a:bool[100] = gt b 0.0:f32[]
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:66:17 (compute_optimized_summary_stats)
#
#   operation c:f32[100] = jit[
#   name=_where
#   jaxpr={ lambda ; a:bool[100] b:f32[100] d:f32[]. let
#       e:f32[] = convert_element_type[new_dtype=float32 weak_type=False] d
#       f:f32[100] = broadcast_in_dim[
#         broadcast_dimensions=()
#         shape=(100,)
#         sharding=None
#       ] e
#       c:f32[100] = select_n a f b
#     in (c,) }
# ] a b inf:f32[]
#     from line /Users/laura.driscoll/Documents/code/Aind.Behavior.VrForaging.Analysis/src/aind_behavior_vrforaging_analysis/sbi_ddm_analysis/enhanced_stats.py:78:18 (compute_optimized_summary_stats)
#
# (Additional originating lines are not shown.)
#
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.ConcretizationTypeError

# %%
def parameter_sensitivity_analysis():
    """
    For each parameter, vary it while holding others constant.
    See which summary stats are most sensitive.
    """
    rng_key = random.PRNGKey(42)
    
    # Base parameter values (middle of prior)
    base_theta = jnp.array([1.0, 1.0, 1.0, 0.275])
    
    param_names = ["drift_rate", "reward_bump", "failure_bump", "noise_std"]
    param_ranges = {
        'drift_rate': jnp.linspace(0.0, 2.0, 15),
        'reward_bump': jnp.linspace(0.0, 2.0, 15),
        'failure_bump': jnp.linspace(0.0, 2.0, 15),
        'noise_std': jnp.linspace(0.05, 0.5, 15),
    }
    
    results = {}
    
    for param_idx, (param_name, param_values) in enumerate(param_ranges.items()):
        print(f"\nAnalyzing sensitivity to {param_name}...")
        
        stats_for_param = []
        
        for param_val in param_values:
            # Create theta with one parameter varied
            theta = base_theta.at[param_idx].set(param_val)
            
            # Average over 50 simulations to reduce noise
            stats_samples = []
            for _ in range(50):
                rng_key, subkey = random.split(rng_key)
                _, stats, _ = simulate_and_extract(theta, subkey)
                stats_samples.append(stats)
            
            mean_stats = np.mean(stats_samples, axis=0)
            stats_for_param.append(mean_stats)
        
        results[param_name] = {
            'values': param_values,
            'stats': np.array(stats_for_param)  # (15, 37)
        }
    
    # === COMPUTE SENSITIVITY SCORES ===
    from scipy.stats import spearmanr
    
    sensitivity_matrix = np.zeros((4, len(FEATURE_NAMES)))
    
    for param_idx, param_name in enumerate(param_names):
        param_values = results[param_name]['values']
        param_stats = results[param_name]['stats']
        
        for stat_idx in range(len(FEATURE_NAMES)):
            # Spearman correlation between parameter value and stat value
            corr, _ = spearmanr(param_values, param_stats[:, stat_idx])
            sensitivity_matrix[param_idx, stat_idx] = abs(corr)
    
    # === PLOT SENSITIVITY HEATMAP ===
    fig, ax = plt.subplots(figsize=(16, 6))
    im = ax.imshow(sensitivity_matrix, cmap='YlOrRd', aspect='auto', vmin=0, vmax=1)
    
    ax.set_yticks(range(4))
    ax.set_yticklabels(param_names, fontsize=10)
    ax.set_xticks(range(len(FEATURE_NAMES)))
    ax.set_xticklabels(FEATURE_NAMES, rotation=90, ha='right', fontsize=8)
    
    plt.colorbar(im, ax=ax, label='|Spearman correlation|')
    plt.title('Parameter Sensitivity: Which stats respond to which parameters?', fontsize=14)
    plt.tight_layout()
    plt.savefig('parameter_sensitivity.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    # === IDENTIFY MOST SENSITIVE STATS PER PARAMETER ===
    print("\n" + "="*70)
    print("TOP 5 MOST SENSITIVE STATS FOR EACH PARAMETER")
    print("="*70)
    
    for param_idx, param_name in enumerate(param_names):
        print(f"\n{param_name.upper()}:")
        
        # Get top 5 stats
        top_indices = np.argsort(sensitivity_matrix[param_idx])[::-1][:5]
        
        for rank, stat_idx in enumerate(top_indices, 1):
            corr = sensitivity_matrix[param_idx, stat_idx]
            print(f"  {rank}. {FEATURE_NAMES[stat_idx]:<30} (|r| = {corr:.3f})")
    
    # === IDENTIFY WEAK STATS (not sensitive to anything) ===
    print("\n" + "="*70)
    print("WEAK STATS (max sensitivity < 0.3 to any parameter)")
    print("="*70)
    
    max_sensitivity = sensitivity_matrix.max(axis=0)
    weak_stats = np.where(max_sensitivity < 0.3)[0]
    
    for stat_idx in weak_stats:
        print(f"{FEATURE_NAMES[stat_idx]:<30} (max |r| = {max_sensitivity[stat_idx]:.3f})")
    
    return results, sensitivity_matrix

# Run sensitivity analysis
sensitivity_results, sensitivity_matrix = parameter_sensitivity_analysis()
# Out:
# Analyzing sensitivity to drift_rate...
#
# Analyzing sensitivity to reward_bump...
#
# Analyzing sensitivity to failure_bump...
#
# Analyzing sensitivity to noise_std...
# ======================================================================
# TOP 5 MOST SENSITIVE STATS FOR EACH PARAMETER
# ======================================================================
#
# DRIFT_RATE:
#   1. p75                            (|r| = 1.000)
#   2. stop_rate                      (|r| = 1.000)
#   3. median                         (|r| = 1.000)
#   4. late_mean                      (|r| = 1.000)
#   5. early_mean                     (|r| = 1.000)
#
# REWARD_BUMP:
#   1. p75                            (|r| = 1.000)
#   2. autocorr_lag1                  (|r| = 1.000)
#   3. mean_time                      (|r| = 1.000)
#   4. std_time                       (|r| = 1.000)
#   5. mean_stops                     (|r| = 1.000)
#
# FAILURE_BUMP:
#   1. after_failure_cv               (|r| = 0.954)
#   2. std_time_after_failure         (|r| = 0.946)
#   3. reward_effect_predictability   (|r| = 0.946)
#   4. mean_time_after_failure        (|r| = 0.907)
#   5. signal_to_noise                (|r| = 0.900)
#
# NOISE_STD:
#   1. mean_time_after_failure        (|r| = 0.993)
#   2. after_failure_cv               (|r| = 0.989)
#   3. std_time_after_failure         (|r| = 0.982)
#   4. reward_effect_predictability   (|r| = 0.975)
#   5. mean_stops                     (|r| = 0.957)
#
# ======================================================================
# WEAK STATS (max sensitivity < 0.3 to any parameter)
# ======================================================================

# %%
# === Sweep Setup ===
theta_labels = ["drift_rate", "reward_bump", "failure_bump", "noise_std"]
theta_base = jnp.array([0.4, 0.3, 0.1, 0.1])  # Base parameters

n_repeats = 20  # Runs per parameter combination
gradient_values = np.linspace(0.01, 1.0, 5)  # 5 levels for gradient
x_values = np.linspace(0.01, 1.0, 10)  # 10 points for x-axis

# Storage for results
results_mean = {label: {} for label in theta_labels}
results_sem = {label: {} for label in theta_labels}

print(f"Will run {len(theta_labels)} parameter sweeps")
print(f"Each sweep: {len(gradient_values)} gradients × {len(x_values)} x-values × {n_repeats} repeats")
print(f"Total simulations: {len(theta_labels) * len(gradient_values) * len(x_values) * n_repeats}")
# Out:
# Will run 4 parameter sweeps
# Each sweep: 5 gradients × 10 x-values × 20 repeats
# Total simulations: 4000

# %%
# === Run Parameter Sweeps ===
import time

start_time = time.time()

for param_idx, param_x in enumerate(theta_labels):
    print(f"\nSweeping {param_x} ({param_idx+1}/{len(theta_labels)})...")
    
    # Get other parameters (for gradient and fixed)
    other_params = [p for j, p in enumerate(theta_labels) if j != param_idx]
    gradient_param_idx = theta_labels.index(other_params[0])  # First other param varies
    
    for grad_val in gradient_values:
        mean_list, sem_list = [], []
        
        for x_val in x_values:
            # Build theta for this combination
            theta = theta_base.copy()
            theta = theta.at[param_idx].set(x_val)  # X-axis parameter
            theta = theta.at[gradient_param_idx].set(grad_val)  # Gradient parameter
            # Other parameters stay at base values
            
            # Run multiple simulations
            runs = []
            for _ in range(n_repeats):
                _, summary, rng_key = simulate_and_extract(theta, rng_key)
                runs.append(np.array(summary))
            
            runs = np.vstack(runs)
            mean_list.append(runs.mean(axis=0))
            sem_list.append(runs.std(axis=0, ddof=1) / np.sqrt(n_repeats))
        
        # Store results
        key = f"{grad_val:.4f}"
        results_mean[param_x][key] = np.vstack(mean_list)
        results_sem[param_x][key] = np.vstack(sem_list)
    
    elapsed = time.time() - start_time
    print(f"  Completed in {elapsed:.1f}s")

total_time = time.time() - start_time
print(f"\n✓ All sweeps completed in {total_time/60:.1f} minutes")
# Out:
# Sweeping drift_rate (1/4)...
#   Completed in 0.9s
#
# Sweeping reward_bump (2/4)...
#   Completed in 1.2s
#
# Sweeping failure_bump (3/4)...
#   Completed in 1.4s
#
# Sweeping noise_std (4/4)...
#   Completed in 1.7s
#
# ✓ All sweeps completed in 0.0 minutes

# %% [markdown]
# ## Visualization 1: Key Features by Parameter
#
# Focus on the most important features for each parameter:
# - **drift_rate**: Basic time statistics, temporal trends
# - **reward_bump**: Reward history effects (mean_time_after_reward)
# - **failure_bump**: Reward history effects (mean_time_after_failure)
# - **noise_std**: Distribution shape, sequential dependencies

# %%
# === Visualization 1: Most Important Features ===

# Define key features to visualize for each parameter
KEY_FEATURES = {
    "drift_rate": [1, 2, 11, 12, 13],  # mean_time, std_time, early_mean, late_mean, trend
    "reward_bump": [7, 8, 9, 14, 23],  # After reward/failure, late-early, reward_rate
    "failure_bump": [7, 8, 9, 10, 14], # After reward/failure stats
    "noise_std": [2, 16, 18, 19, 20],  # std_time, p25, p75, iqr, autocorr
}

for param_x in theta_labels:
    other_params = [p for j, p in enumerate(theta_labels) if p != param_x]
    gradient_param = other_params[0]
    
    # Get key features for this parameter
    feature_indices = KEY_FEATURES[param_x]
    
    fig, axes = plt.subplots(1, len(feature_indices), figsize=(4*len(feature_indices), 4))
    if len(feature_indices) == 1:
        axes = [axes]
    
    fig.suptitle(f"Effect of {param_x} (gradient: {gradient_param})", fontsize=14, fontweight='bold')
    
    cmap = plt.cm.viridis(np.linspace(0, 1, len(gradient_values)))
    
    for ax_idx, feature_idx in enumerate(feature_indices):
        ax = axes[ax_idx]
        feature_name = FEATURE_NAMES[feature_idx]
        
        for color_idx, grad_val in enumerate(gradient_values):
            key = f"{grad_val:.4f}"
            mean_vals = results_mean[param_x][key][:, feature_idx]
            sem_vals = results_sem[param_x][key][:, feature_idx]
            
            ax.plot(x_values, mean_vals, color=cmap[color_idx], 
                   marker='o', markersize=4, linewidth=2,
                   label=f"{grad_val:.2f}")
            ax.fill_between(x_values,
                          mean_vals - 1.96 * sem_vals,
                          mean_vals + 1.96 * sem_vals,
                          color=cmap[color_idx], alpha=0.2)
        
        ax.set_title(feature_name, fontsize=11, fontweight='bold')
        ax.set_xlabel(param_x, fontsize=10)
        ax.set_ylabel('Value', fontsize=10)
        ax.grid(True, linestyle='--', alpha=0.3)
    
    # Add legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5),
              title=gradient_param, fontsize=9)
    
    plt.tight_layout(rect=[0, 0, 0.95, 0.96])
    plt.show()

# %% [markdown]
# ## Visualization 2: Feature Groups
#
# Visualize all features organized by functional groups.

# %%
# === Visualization 2: All Features by Group ===

for param_x in theta_labels:
    other_params = [p for j, p in enumerate(theta_labels) if p != param_x]
    gradient_param = other_params[0]
    
    # Create one large figure with subplots for each feature group
    fig = plt.figure(figsize=(20, 12))
    fig.suptitle(f"All Features: {param_x} (gradient: {gradient_param})", 
                fontsize=16, fontweight='bold', y=0.995)
    
    cmap = plt.cm.viridis(np.linspace(0, 1, len(gradient_values)))
    
    # Create subplots for each group
    group_row = 0
    for group_name, feature_indices in FEATURE_GROUPS.items():
        n_features = len(feature_indices)
        
        # Add group title
        ax_title = plt.subplot(8, 7, group_row * 7 + 1)
        ax_title.text(0.5, 0.5, group_name, fontsize=12, fontweight='bold',
                     ha='center', va='center')
        ax_title.axis('off')
        
        # Plot features in this group
        for i, feature_idx in enumerate(feature_indices):
            ax = plt.subplot(8, 7, group_row * 7 + i + 2)
            feature_name = FEATURE_NAMES[feature_idx]
            
            for color_idx, grad_val in enumerate(gradient_values):
                key = f"{grad_val:.4f}"
                mean_vals = results_mean[param_x][key][:, feature_idx]
                sem_vals = results_sem[param_x][key][:, feature_idx]
                
                ax.plot(x_values, mean_vals, color=cmap[color_idx], 
                       marker='o', markersize=3, linewidth=1.5, alpha=0.8)
                ax.fill_between(x_values,
                              mean_vals - 1.96 * sem_vals,
                              mean_vals + 1.96 * sem_vals,
                              color=cmap[color_idx], alpha=0.15)
            
            ax.set_title(feature_name, fontsize=8)
            ax.tick_params(labelsize=7)
            ax.grid(True, linestyle='--', alpha=0.3)
        
        group_row += 1
    
    # Add legend
    legend_ax = plt.subplot(7, 7, 49)
    for color_idx, grad_val in enumerate(gradient_values):
        legend_ax.plot([], [], color=cmap[color_idx], linewidth=3, 
                      label=f"{grad_val:.2f}")
    legend_ax.legend(title=gradient_param, loc='center', fontsize=8)
    legend_ax.axis('off')
    
    plt.tight_layout(rect=[0, 0, 1, 0.99])
    plt.show()
# Out:
# /var/folders/rv/bpj1qnwx5lz32q8rr9jxs07h0000gp/T/ipykernel_81771/1943248076.py:56: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout(rect=[0, 0, 1, 0.99])

# %% [markdown]
# ## Visualization 3: Reward History Effects
#
# Deep dive into the critical reward history features that distinguish reward_bump from failure_bump.

# %%
# === Visualization 3: Reward History Deep Dive ===

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Reward History Effects: Critical Features for Bump Parameters', 
            fontsize=14, fontweight='bold')

# Feature indices for reward history
reward_features = [7, 8, 9, 10]  # After reward mean/std, after failure mean/std
params_to_show = ['reward_bump', 'failure_bump']

for param_idx, param_x in enumerate(params_to_show):
    other_params = [p for j, p in enumerate(theta_labels) if p != param_x]
    gradient_param = other_params[0]
    
    cmap = plt.cm.viridis(np.linspace(0, 1, len(gradient_values)))
    
    for feat_idx, feature_idx in enumerate(reward_features):
        ax = axes[param_idx, feat_idx]
        feature_name = FEATURE_NAMES[feature_idx]
        
        for color_idx, grad_val in enumerate(gradient_values):
            key = f"{grad_val:.4f}"
            mean_vals = results_mean[param_x][key][:, feature_idx]
            sem_vals = results_sem[param_x][key][:, feature_idx]
            
            ax.plot(x_values, mean_vals, color=cmap[color_idx], 
                   marker='o', markersize=5, linewidth=2.5,
                   label=f"{gradient_param}={grad_val:.2f}")
            ax.fill_between(x_values,
                          mean_vals - 1.96 * sem_vals,
                          mean_vals + 1.96 * sem_vals,
                          color=cmap[color_idx], alpha=0.2)
        
        ax.set_title(f"{param_x} → {feature_name}", fontsize=11, fontweight='bold')
        ax.set_xlabel(param_x, fontsize=10)
        ax.set_ylabel('Time (s)', fontsize=10)
        ax.grid(True, linestyle='--', alpha=0.3)
        
        if feat_idx == 0:
            ax.legend(fontsize=8, loc='best')

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

print("\nKey Insight:")
print("  • reward_bump should primarily affect 'mean_time_after_reward' (feature 7)")
print("  • failure_bump should primarily affect 'mean_time_after_failure' (feature 8)")
print("  • These features enable parameter identifiability!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 18
#      15 cmap = plt.cm.viridis(np.linspace(0, 1, len(gradient_values)))
#      17 for feat_idx, feature_idx in enumerate(reward_features):
# ---> 18     ax = axes[param_idx, feat_idx]
#      19     feature_name = FEATURE_NAMES[feature_idx]
#      21     for color_idx, grad_val in enumerate(gradient_values):
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %% [markdown]
# ## Visualization 4: Feature Sensitivity Heatmap
#
# Show which features are most sensitive to each parameter.

# %%
# === Visualization 4: Sensitivity Heatmap ===

# Compute sensitivity as the range (max - min) of each feature
# across parameter values (using middle gradient value)
sensitivity_matrix = np.zeros((len(theta_labels), len(FEATURE_NAMES)))

middle_gradient_idx = len(gradient_values) // 2
middle_gradient_val = gradient_values[middle_gradient_idx]
key = f"{middle_gradient_val:.4f}"

for param_idx, param_x in enumerate(theta_labels):
    means = results_mean[param_x][key]
    for feat_idx in range(len(FEATURE_NAMES)):
        # Compute normalized range
        feat_values = means[:, feat_idx]
        feat_range = np.max(feat_values) - np.min(feat_values)
        feat_mean = np.mean(feat_values)
        # Normalize by mean to get relative sensitivity
        sensitivity_matrix[param_idx, feat_idx] = feat_range / (np.abs(feat_mean) + 1e-6)

# Plot heatmap
fig, ax = plt.subplots(figsize=(16, 6))

im = ax.imshow(sensitivity_matrix, aspect='auto', cmap='YlOrRd', interpolation='nearest')

# Set ticks and labels
ax.set_xticks(np.arange(len(FEATURE_NAMES)))
ax.set_yticks(np.arange(len(theta_labels)))
ax.set_xticklabels(FEATURE_NAMES, rotation=90, fontsize=8)
ax.set_yticklabels(theta_labels, fontsize=10)

# Add colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Relative Sensitivity (Range/Mean)', rotation=270, labelpad=20)

# Add title
ax.set_title('Feature Sensitivity to Parameters (Higher = More Informative)', 
            fontsize=12, fontweight='bold', pad=20)

# Add grid
ax.set_xticks(np.arange(len(FEATURE_NAMES)) - 0.5, minor=True)
ax.set_yticks(np.arange(len(theta_labels)) - 0.5, minor=True)
ax.grid(which='minor', color='white', linestyle='-', linewidth=1)

plt.tight_layout()
plt.show()

# Print top features for each parameter
print("\nTop 5 Most Sensitive Features per Parameter:")
print("="*70)
for param_idx, param_x in enumerate(theta_labels):
    top_indices = np.argsort(sensitivity_matrix[param_idx])[-5:][::-1]
    print(f"\n{param_x}:")
    for rank, idx in enumerate(top_indices, 1):
        sens = sensitivity_matrix[param_idx, idx]
        print(f"  {rank}. {FEATURE_NAMES[idx]:30s} (sensitivity: {sens:.3f})")

# %% [markdown]
# ## Visualization 5: Pairwise Feature Relationships
#
# Examine correlations between key features to understand redundancy.

# %%
# === Visualization 5: Feature Correlation Analysis ===

# Collect all feature values across all simulations
all_features = []

for param_x in theta_labels:
    for key in results_mean[param_x].keys():
        # Get all x-values for this gradient level
        all_features.append(results_mean[param_x][key])

all_features = np.vstack(all_features)

# Compute correlation matrix
corr_matrix = np.corrcoef(all_features.T)

# Plot correlation heatmap
fig, ax = plt.subplots(figsize=(18, 16))

im = ax.imshow(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, aspect='auto')

# Set ticks
ax.set_xticks(np.arange(len(FEATURE_NAMES)))
ax.set_yticks(np.arange(len(FEATURE_NAMES)))
ax.set_xticklabels(FEATURE_NAMES, rotation=90, fontsize=9)
ax.set_yticklabels(FEATURE_NAMES, fontsize=9)

# Add colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Correlation', rotation=270, labelpad=20)

# Add title
ax.set_title('Feature Correlation Matrix (All Parameters)', 
            fontsize=14, fontweight='bold', pad=20)

# Add grid lines at group boundaries
group_boundaries = [0]
for group_indices in FEATURE_GROUPS.values():
    group_boundaries.append(group_boundaries[-1] + len(group_indices))

for boundary in group_boundaries[1:-1]:
    ax.axhline(boundary - 0.5, color='black', linewidth=2)
    ax.axvline(boundary - 0.5, color='black', linewidth=2)

plt.tight_layout()
plt.show()

# Find highly correlated feature pairs (|corr| > 0.9)
high_corr_pairs = []
for i in range(len(FEATURE_NAMES)):
    for j in range(i+1, len(FEATURE_NAMES)):
        if abs(corr_matrix[i, j]) > 0.9:
            high_corr_pairs.append((FEATURE_NAMES[i], FEATURE_NAMES[j], corr_matrix[i, j]))

if high_corr_pairs:
    print("\nHighly Correlated Features (|r| > 0.9):")
    print("="*70)
    for feat1, feat2, corr in sorted(high_corr_pairs, key=lambda x: abs(x[2]), reverse=True):
        print(f"  {feat1:30s} <-> {feat2:30s}: r={corr:+.3f}")
    print("\nNote: Highly correlated features may be redundant for inference.")
else:
    print("\n✓ No highly correlated features (|r| > 0.9)")
    print("  This is good - features are relatively independent!")
